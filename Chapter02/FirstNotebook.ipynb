# %%
print("this is my first line of code in jupyter notebooks")
# Out:
# this is my first line of code in jupyter notebooks

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB 93.9 kB/s eta 0:01:55
#      --------------------------------------- 0.0/10.7 MB 131.3 kB/s eta 0:01:22
#      --------------------------------------- 0.1/10.7 MB 187.9 kB/s eta 0:00:57
#      --------------------------------------- 0.1/10.7 MB 425.1 kB/s eta 0:00:25
#      -- ------------------------------------- 0.6/10.7 MB 1.9 MB/s eta 0:00:06
#      --- ------------------------------------ 0.9/10.7 MB 2.3 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.2/10.7 MB 2.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.4/10.7 MB 3.0 MB/s eta 0:00:04
#      ------ --------------------------------- 1.7/10.7 MB 3.4 MB/s eta 0:00:03
# ...
