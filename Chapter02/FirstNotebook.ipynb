# %%
print("this is my first line of code in jupyter notebooks")
# Out:
# this is my first line of code in jupyter notebooks

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 12.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [2422 lines of output]
#       Partial import of sklearn during the build process.
#       clang: error: unsupported option '-fopenmp'
#       clang: error: unsupported option '-fopenmp'
#       /private/var/folders/qz/ncpxlmfj0ln46r4kg3jylt140000gn/T/pip-install-1mzox2bz/scikit-learn_35974fd84d4d49128342c1a72ba646dd/sklearn/_build_utils/openmp_helpers.py:130: UserWarning:
#
#                       ***********
#                       * WARNING *
#                       ***********
#
#       It seems that scikit-learn cannot be built with OpenMP.
#
#       - Make sure you have followed the installation instructions:
#
# ...
